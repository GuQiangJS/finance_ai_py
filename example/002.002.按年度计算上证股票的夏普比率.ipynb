# %%
import pandas as pd
import matplotlib.pyplot as plt
import quantaxis_ext
import ploter
import talib
import numpy as np
import settings
import units
import header
import calculator as calc

#设定绘图的默认大小
import matplotlib

#加载 seaborn，并且设置默认使用 seaborn
import seaborn as sns
sns.set()

matplotlib.rcParams['font.family'] = 'sans-serif'
matplotlib.rcParams['font.sans-serif'] = ['SimHei']
matplotlib.rcParams['axes.unicode_minus']=False #用来正常显示负号

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
zs_code='000001'
years=[y for y in range(1991,2019)]
year=years[-1]

# %% [markdown]
# ## 读取股票列表

# %%
#上证所有股票的列表
stock_list=quantaxis_ext.fetch_stock_list()
stock_list=stock_list[stock_list['sse']=='sh']
stock_list.tail()
# Out:
#           code  decimal_point  name  pre_close       sec sse  volunit
# code
# 603993  603993              2  洛阳钼业  7426.0075  stock_cn  sh      100
# 603996  603996              2  中新科技     8.0200  stock_cn  sh      100
# 603997  603997              2  继峰股份     7.6300  stock_cn  sh      100
# 603998  603998              2  方盛制药     4.9700  stock_cn  sh      100
# 603999  603999              2  读者传媒     5.0700  stock_cn  sh      100

# %% [markdown]
# ## 年度 Sharpe ratio

# %%
#全部夏普比率表
sharpe_ratio_all=pd.DataFrame(stock_list['name'])

# %%
for y in years:
    sr=calc.calc_sharp_radio(stock_list['code'],zs_code,'{0}-01-01'.format(y),'{0}-12-31'.format(y))
    sharpe_ratio_all[y]=sr
# Out:
# QA Error QA_fetch_stock_day_adv parameter code=600000 , start=1991-01-01, end=1991-12-31 call QA_fetch_stock_day return None
# QA Error QA_fetch_stock_day_adv parameter code=600004 , start=1991-01-01, end=1991-12-31 call QA_fetch_stock_day return None
# QA Error QA_fetch_stock_day_adv parameter code=600006 , start=1991-01-01, end=1991-12-31 call QA_fetch_stock_day return None
# QA Error QA_fetch_stock_day_adv parameter code=600007 , start=1991-01-01, end=1991-12-31 call QA_fetch_stock_day return None
# QA Error QA_fetch_stock_day_adv parameter code=600008 , start=1991-01-01, end=1991-12-31 call QA_fetch_stock_day return None
# QA Error QA_fetch_stock_day_adv parameter code=600009 , start=1991-01-01, end=1991-12-31 call QA_fetch_stock_day return None
# QA Error QA_fetch_stock_day_adv parameter code=600010 , start=1991-01-01, end=1991-12-31 call QA_fetch_stock_day return None
# ...

# %%
sharpe_ratio_all

# %%
sharpe_ratio_all.drop(columns=['name']).T

# %%
sharpe_ratio_all.drop(columns=['name']).T.describe()
