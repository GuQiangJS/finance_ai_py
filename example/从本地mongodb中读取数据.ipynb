# %%
from QUANTAXIS.QAFetch.QAQuery import QA_fetch_stock_day

QA_fetch_stock_day('000002','1990-01-01','2018-12-31')
# Out:
# array([['000002', 11.1, 11.4, ..., 2890.0, 3294600.0,
#         Timestamp('1991-12-23 00:00:00')],
#        ['000002', 11.45, 12.5, ..., 6335.0, 7918750.0,
#         Timestamp('1991-12-24 00:00:00')],
#        ['000002', 12.4, 13.0, ..., 4905.0, 5935050.0,
#         Timestamp('1991-12-25 00:00:00')],
#        ...,
#        ['000002', 23.84, 23.98, ..., 221987.0, 528530976.0,
#         Timestamp('2018-12-26 00:00:00')],
#        ['000002', 24.25, 24.56, ..., 352501.0, 849242368.0,
#         Timestamp('2018-12-27 00:00:00')],
#        ['000002', 23.67, 24.24, ..., 322810.0, 772703680.0,
#         Timestamp('2018-12-28 00:00:00')]], dtype=object)

# %%
#https://github.com/QUANTAXIS/QUANTAXIS/blob/master/QUANTAXIS/QAData/base_datastruct.py

from QUANTAXIS.QAFetch.QAQuery_Advance import QA_fetch_stock_day_adv
qaDAStruct = QA_fetch_stock_day_adv('000002')
qaDAStruct.to_pd().head()
# Out:
#                     open  high   low  close  volume     amount
# date       code
# 1991-12-23 000002  11.10  11.4  11.1  11.40  2890.0  3294600.0
# 1991-12-24 000002  11.45  12.5  11.4  12.50  6335.0  7918750.0
# 1991-12-25 000002  12.40  13.0  12.0  12.10  4905.0  5935050.0
# 1991-12-26 000002  12.20  12.2  11.8  12.10  4915.0  5947150.0
# 1991-12-27 000002  12.15  12.2  11.9  12.15  4405.0  5352075.0

# %%
qaDAStruct.to_qfq().to_pd().head(5)
# Out:
#                        open      high       low     close         volume  \
# date       code
# 1991-12-23 000002  0.118916  0.122130  0.118916  0.122130  269761.225999
# 1991-12-24 000002  0.122666  0.133915  0.122130  0.133915  591327.808548
# 1991-12-25 000002  0.132843  0.139271  0.128558  0.129629  457847.340320
# 1991-12-26 000002  0.130701  0.130701  0.126415  0.129629  458780.770168
# 1991-12-27 000002  0.130165  0.130701  0.127487  0.130165  411175.847933
#
#                       amount  preclose       adj
# date       code
# 1991-12-23 000002  3294600.0       NaN  0.010713
# 1991-12-24 000002  7918750.0  0.122130  0.010713
# 1991-12-25 000002  5935050.0  0.133915  0.010713
# 1991-12-26 000002  5947150.0  0.129629  0.010713
# 1991-12-27 000002  5352075.0  0.129629  0.010713

# %%
qaDAStruct.to_hfq().to_pd().head(5)
# Out:
#                     open  high   low  close  volume     amount  preclose  adj
# date       code
# 1991-12-23 000002  11.10  11.4  11.1  11.40  2890.0  3294600.0       NaN  1.0
