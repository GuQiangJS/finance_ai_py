# %% [markdown]
# # QA_fetch_stock_list使用示例

# %%
import QUANTAXIS as QA
import os
import sys

# %%
QA.QA_fetch_stock_list()
# Out:
#           code  decimal_point  name    pre_close       sec sse  volunit
# code
# 000001  000001              2  平安银行   584.000000  stock_cn  sz      100
# 000002  000002              2  万 科Ａ    24.969999  stock_cn  sz      100
# 000004  000004              2  国农科技    16.440001  stock_cn  sz      100
# 000005  000005              2  世纪星源  4034.005625  stock_cn  sz      100
# 000006  000006              2  深振业Ａ     5.260000  stock_cn  sz      100
# 000007  000007              2   全新好     6.880000  stock_cn  sz      100
# 000008  000008              2  神州高铁  8002.006875  stock_cn  sz      100
# 000009  000009              2  中国宝安     4.380000  stock_cn  sz      100
# 000010  000010              2  美丽生态  5762.013750  stock_cn  sz      100
# 000011  000011              2  深物业A   424.045000  stock_cn  sz      100
# 000012  000012              2  南 玻Ａ     4.150000  stock_cn  sz      100
# 000014  000014              2  沙河股份   440.032500  stock_cn  sz      100
# ...
