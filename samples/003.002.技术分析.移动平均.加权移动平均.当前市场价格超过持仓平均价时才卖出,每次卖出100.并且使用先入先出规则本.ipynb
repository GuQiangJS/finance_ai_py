# %% [markdown]
# https://zh.wikipedia.org/wiki/%E7%A7%BB%E5%8B%95%E5%B9%B3%E5%9D%87
#
# [报告](#%E6%8A%A5%E5%91%8A)

# %%
import warnings
warnings.filterwarnings('ignore')
import QUANTAXIS as QA
import talib
import jupyter_helper
import numpy as np
from pyecharts import Line

import os
os.path.abspath(os.path.dirname(os.getcwd()))
import sys
sys.path.append(os.path.abspath(os.path.dirname(os.getcwd())))

from finance_ai_py import quantaxis_ext
from talib import MA_Type

# %%
s,e=jupyter_helper.get_start_end_date()
benchmark_code=jupyter_helper.get_benchmark_code()
stock_code='600436'
timeperiod=5
nbdevup=2
nbdevdn=2
INIT_CASH=10000
MATYPE=MA_Type.WMA

# %%
stock_data=QA.QA_fetch_stock_day_adv(stock_code,s,e)

# %%
from talib import MA_Type
df=stock_data.data
df['qfq_close']=stock_data.to_qfq().data['close']
df=df.reset_index().set_index('date')
df['DAILY_RETURN']=np.round(jupyter_helper.calc_daily_return(df['close']),4)
df['WMA_UPPER'],df['WMA_MIDDLE'],df['WMA_LOWER']=talib.BBANDS(np.array(df['qfq_close']), timeperiod=timeperiod, nbdevup=nbdevup, nbdevdn=nbdevdn,matype=MATYPE)
df=df.dropna()

# %%
df
# Out:
#               code   open   high    low  close   volume       amount  \
# date
# 2005-01-10  600436  11.39  11.46  11.35  11.40   1544.0    1762106.0
# 2005-01-11  600436  11.40  11.48  11.31  11.48   2179.0    2488290.0
# 2005-01-12  600436  11.48  11.48  11.36  11.42   1910.0    2180402.0
# 2005-01-13  600436  11.41  11.45  11.20  11.26   3609.0    4080836.0
# 2005-01-14  600436  11.24  11.40  11.21  11.25   2494.0    2808243.0
# 2005-01-17  600436  11.13  11.36  11.10  11.19   2491.0    2786137.0
# 2005-01-18  600436  11.20  11.40  11.18  11.37   2798.0    3160824.0
# 2005-01-19  600436  11.36  11.36  11.20  11.22   1426.0    1602674.0
# 2005-01-20  600436  11.18  11.22  11.08  11.18   3354.0    3731700.0
# 2005-01-21  600436  11.10  11.37  10.95  11.34   6487.0    7207665.0
# 2005-01-25  600436  11.49  11.72  11.30  11.70   6365.0    7327900.0
# 2005-01-26  600436  11.65  11.70  11.50  11.56   2099.0    2439923.0
# 2005-01-27  600436  11.50  11.60  11.44  11.51   1175.0    1356029.0
# 2005-01-28  600436  11.40  11.51  11.35  11.49   1579.0    1805004.0
# 2005-01-31  600436  11.32  11.63  11.32  11.46   2320.0    2661155.0
# 2005-02-01  600436  11.55  11.58  11.36  11.38   1455.0    1664551.0
# 2005-02-02  600436  11.30  11.89  11.30  11.87   3654.0    4270490.0
# 2005-02-03  600436  11.90  11.90  11.62  11.68   2679.0    3146621.0
# 2005-02-04  600436  11.68  12.07  11.58  12.02   5389.0    6428419.0
# 2005-02-16  600436  12.04  12.40  12.04  12.11   3752.0    4576814.0
# 2005-02-17  600436  11.97  12.28  11.90  12.18   1914.0    2317955.0
# 2005-02-18  600436  12.15  12.30  12.12  12.30   4688.0    5738922.0
# 2005-02-21  600436  12.30  12.78  12.30  12.72  10385.0   13125683.0
# 2005-02-22  600436  12.72  13.04  12.60  13.01  17878.0   23070556.0
# 2005-02-23  600436  12.99  13.15  12.71  12.95   6522.0    8443091.0
# 2019-01-16  88.000000        0.0092  89.334361   86.500000  83.665639
# 2019-01-17  86.000000       -0.0227  89.050635   86.530000  84.009365
# 2019-01-18  90.580000        0.0533  92.016816   87.993333  83.969850
# 2019-01-21  90.320000       -0.0029  92.562918   89.008000  85.453082
# 2019-01-22  88.360000       -0.0217  92.339761   88.988000  85.636239
# 2019-01-23  88.600000        0.0027  92.262898   88.970667  85.678436
# 2019-01-24  87.990000       -0.0069  90.842416   88.710000  86.577584
#
# [3358 rows x 12 columns]

# %% [markdown]
# ## 绘制日线（前复权）

# %%
line = Line('')
markpoint_b=[]
markpoint_s=[]
for x in df[df['qfq_close']<df['WMA_LOWER']].index:
    markpoint_b.append({"coord":[x.date(),np.round(df.loc[x]['qfq_close'],2)],'name':'buy-{}'.format(x.date())})
for x in df[df['qfq_close']>df['WMA_UPPER']].index:
    markpoint_s.append({"coord":[x.date(),np.round(df.loc[x]['qfq_close'],2)],'name':'sale-{}'.format(x.date())})
# 通过使用同一日线数据但是根据买入/卖出分别绘制的方式，实现不同颜色标记买入和卖出点
line.add('qfq_close_b', df.index.date, np.round(df['qfq_close'], 2),datazoom_extra_type='both',
                 is_datazoom_extra_show=True,
                 datazoom_extra_orient='horizontal',
        mark_point=markpoint_b)
line.add('qfq_close_s', df.index.date, np.round(df['qfq_close'], 2),datazoom_extra_type='both',
                 is_datazoom_extra_show=True,
                 datazoom_extra_orient='horizontal',
        mark_point=markpoint_s)
line.add('WMA_LOWER', df.index.date, np.round(df['WMA_LOWER'], 2),datazoom_extra_type='both',
                 is_datazoom_extra_show=True,
                 datazoom_extra_orient='horizontal')
line.add('WMA_UPPER', df.index.date, np.round(df['WMA_UPPER'], 2),datazoom_extra_type='both',
                 is_datazoom_extra_show=True,
                 datazoom_extra_orient='horizontal')
line.add('WMA_MIDDLE', df.index.date, np.round(df['WMA_MIDDLE'], 2),datazoom_extra_type='both',
                 is_datazoom_extra_show=True,
                 datazoom_extra_orient='horizontal')
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="fac048fd58fb4e90b607ceb6c6021cca" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_fac048fd58fb4e90b607ceb6c6021cca = echarts.init(document.getElementById('fac048fd58fb4e90b607ceb6c6021cca'), 'light', {renderer: 'canvas'});
#
# var option_fac048fd58fb4e90b607ceb6c6021cca = {
#     "tooltip": {
#         "axisPointer": {
#             "type": "line"
#         },
#         "trigger": "item",
#         "textStyle": {
#             "fontSize": 14
#         },
#         "borderWidth": 0,
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "triggerOn": "mousemove|click",
#         "borderColor": "#333"
#     },
#     "animation": true,
#     "legend": [
#         {
#             "data": [
#                 "qfq_close_b",
#                 "qfq_close_s",
#                 "WMA_LOWER",
#                 "WMA_UPPER",
#                 "WMA_MIDDLE"
#             ],
#             "show": true,
#             "top": "top",
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "left": "center",
#             "selectedMode": "multiple",
#             "orient": "horizontal"
#         }
#     ],
#     "series_id": 3099759,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "title": [
#         {
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "left": "auto",
#             "subtextStyle": {
#                 "fontSize": 12
#             },
#             "top": "auto"
#         }
#     ],
#     "yAxis": [
#         {
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "show": true,
#             "nameGap": 25,
#             "boundaryGap": true,
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameLocation": "middle",
#             "axisLabel": {
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "interval": "auto",
#                 "margin": 8,
#                 "rotate": 0,
#                 "formatter": "{value} "
#             },
#             "inverse": false,
#             "splitLine": {
#                 "show": true
#             },
#             "type": "value"
#         }
#     ],
#     "xAxis": [
#         {
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "nameLocation": "middle",
#             "type": "category",
#             "data": [
#                 "2005-01-10",
#                 "2005-01-11",
#                 "2005-01-12",
#                 "2005-01-13",
#                 "2005-01-14",
#                 "2005-01-17",
#                 "2005-01-18",
#                 "2005-01-19",
#                 "2005-01-20",
#                 "2005-01-21",
#                 "2005-01-25",
#                 "2005-01-26",
#                 "2005-01-27",
#                 "2005-01-28",
#                 "2005-01-31",
#                 "2005-02-01",
#                 "2005-02-02",
#                 "2005-02-03",
#                 "2005-02-04",
#                 "2005-02-16",
#                 "2005-02-17",
#                 "2005-02-18",
#                 "2005-02-21",
#                 "2005-02-22",
#                 "2005-02-23",
#                 "2005-02-24",
#                 "2005-02-25",
#                 "2005-02-28",
#                 "2005-03-01",
#                 "2005-03-02",
#                 "2005-03-03",
#                 "2005-03-04",
#                 "2005-03-07",
#                 "2005-03-08",
#                 "2005-03-09",
#                 "2005-03-10",
#                 "2005-03-11",
#                 "2005-03-14",
#                 "2005-03-15",
#                 "2005-03-16",
#                 "2005-03-17",
#                 "2005-03-18",
#                 "2005-03-21",
#                 "2005-03-22",
#                 "2005-03-23",
#                 "2005-03-24",
#                 "2005-03-25",
#                 "2005-03-28",
#                 "2005-03-29",
#                 "2005-03-30",
#                 "2005-03-31",
#                 "2005-04-01",
#                 "2005-04-04",
#                 "2005-04-05",
#                 "2005-04-06",
#                 "2005-04-07",
#                 "2005-04-08",
#                 "2005-04-11",
#                 "2005-04-12",
#                 "2005-04-13",
#                 "2005-04-14",
#                 "2005-04-15",
#                 "2005-04-18",
#                 "2005-04-19",
#                 "2005-04-20",
#                 "2005-04-21",
#                 "2005-04-22",
#                 "2005-04-25",
#                 "2005-04-27",
#                 "2005-04-28",
#                 "2005-04-29",
#                 "2005-05-09",
#                 "2005-05-10",
#                 "2005-05-11",
#                 "2005-05-12",
#                 "2005-05-13",
#                 "2005-05-16",
#                 "2005-05-17",
#                 "2005-05-18",
#                 "2005-05-19",
#                 "2005-05-20",
#                 "2005-05-23",
#                 "2005-05-24",
#                 "2005-05-25",
#                 "2005-05-26",
#                 "2005-05-27",
#                 "2005-05-30",
#                 "2005-05-31",
#                 "2005-06-01",
#                 "2005-06-02",
#                 "2005-06-03",
#                 "2005-06-06",
#                 "2005-06-07",
#                 "2005-06-08",
#                 "2005-06-09",
#                 "2005-06-10",
#                 "2005-06-13",
#                 "2005-06-14",
#                 "2005-06-15",
#                 "2005-06-16",
#                 "2005-06-17",
#                 "2005-06-20",
#                 "2005-06-21",
#                 "2005-06-22",
#                 "2005-06-23",
#                 "2005-06-24",
#                 "2005-06-27",
#                 "2005-06-28",
#                 "2005-06-29",
#                 "2005-06-30",
#                 "2005-07-01",
#                 "2005-07-04",
#                 "2005-07-05",
#                 "2005-07-06",
#                 "2005-07-07",
#                 "2005-07-08",
#                 "2005-07-11",
#                 "2005-07-12",
#                 "2005-07-13",
#                 "2005-07-14",
#                 "2005-07-15",
#                 "2005-07-18",
#                 "2005-07-19",
#                 "2005-07-20",
#                 "2005-07-21",
#                 "2005-07-22",
#                 "2005-07-25",
#                 "2005-07-26",
#                 "2005-07-27",
#                 "2005-07-28",
#                 "2005-07-29",
#                 "2005-08-01",
#                 "2005-08-02",
#                 "2005-08-03",
#                 "2005-08-04",
#                 "2005-08-05",
#                 "2005-08-08",
#                 "2005-08-09",
#                 "2005-08-10",
#                 "2005-08-11",
#                 "2005-08-12",
#                 "2005-08-15",
#                 "2005-08-16",
#                 "2005-08-17",
#                 "2005-08-18",
#                 "2005-08-19",
#                 "2005-08-22",
#                 "2005-08-23",
#                 "2005-08-24",
#                 "2005-08-25",
#                 "2005-08-26",
#                 "2005-08-29",
#                 "2005-08-30",
#                 "2005-08-31",
#                 "2005-09-01",
#                 "2005-09-02",
#                 "2005-09-05",
#                 "2005-09-06",
#                 "2005-09-0

# %% [markdown]
# ## 模拟下单

# %%
stock_account=quantaxis_ext.QA_Account_Ext(init_cash=INIT_CASH)
amount=100
Broker = QA.QA_BacktestBroker()

for index in df.index:
    if df.loc[index]['qfq_close']<df.loc[index]['SMA_LOWER']:
        order = stock_account.send_order(
                    code=stock_code,
                    time=index.date(),
                    amount=amount,
                    towards=QA.ORDER_DIRECTION.BUY,
                    price=0,
                    order_model=QA.ORDER_MODEL.CLOSE,
                    amount_model=QA.AMOUNT_MODEL.BY_AMOUNT  # 按数量下单
                    # 在按金额下单的时候,应给予 money参数
                    # 在按数量下单的时候,应给予 amount参数
                )
                # print(item.to_json()[0])
        Broker.receive_order(QA.QA_Event(order=order))

        trade_mes = Broker.query_orders(stock_account.account_cookie, 'filled')
        res = trade_mes.loc[order.account_cookie, order.realorder_id]
        order.trade(res.trade_id, res.trade_price, res.trade_amount,res.trade_time) 
    elif df.loc[index]['qfq_close']<df.loc[index]['SMA_UPPER']:
#         if stock_account.sell_available.get(stock_code, 0) >= amount:#当前有可卖的数量时
        if stock_account.sell_available.get(stock_code, 0) >= amount and df.loc[index]['qfq_close']>stock_account.hold_price_fifo().at[stock_code][0]:
            order = stock_account.send_order(
                        code=stock_code,
                        time=index.date(),
                        amount=amount,
#                         amount=stock_account.sell_available.get(stock_code, 0),
                        towards=QA.ORDER_DIRECTION.SELL,
                        price=0,
                        order_model=QA.ORDER_MODEL.CLOSE,
                        amount_model=QA.AMOUNT_MODEL.BY_AMOUNT  # 按数量下单
                        # 在按金额下单的时候,应给予 money参数
                        # 在按数量下单的时候,应给予 amount参数
                    )
                    # print(item.to_json()[0])
            Broker.receive_order(QA.QA_Event(order=order))

            trade_mes = Broker.query_orders(stock_account.account_cookie, 'filled')
            res = trade_mes.loc[order.account_cookie, order.realorder_id]
            order.trade(res.trade_id, res.trade_price, res.trade_amount,res.trade_time)
    stock_account.settle()

# %%
stock_account.history_table

# %%
stock_account.history_table.iloc[stock_account.history_table[stock_account.history_table['amount']<0].tail(1).index.values[0]+1:]

# %%
stock_account.hold_table()

# %% [markdown]
# ## 当前持仓股票（包含买入时间，买入价格等）

# %%
stock_account.hold_table_fifo()

# %% [markdown]
# ## 当前账户剩余资金

# %%
stock_account.cash_available

# %% [markdown]
# ## 持仓成本

# %%
stock_account.hold_price()

# %% [markdown]
# ## 持仓成本（不计算已卖出的交易的成本）

# %%
stock_account.hold_price_fifo()

# %%
e-stock_account.hold_table_fifo().index

# %%
e

# %% [markdown]
# ## 报告

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" 

'以 {0} 作为测试对象。初始资金 {1}。每次交易 {2} 股。'.format(stock_code,INIT_CASH,amount)
'按照 {0} 规则进行交易。'.format(MATYPE)
'卖出时只有当前市场价格超过持仓平均价时才卖出。并且使用先入先出规则。'
'总交易次数 {0} 次。'.format(stock_account.history_table.shape[0])
'当前持仓均价：{0}，持仓数量：{1}。 当前持仓最大天数：{2} 当前持有现金：{3}'.format(
    np.round(stock_account.hold_price_fifo()[stock_code][0],4),
    stock_account.hold_price_fifo()[stock_code][1],
e-stock_account.hold_table_fifo().index[0],
np.round(stock_account.cash_available,4))
