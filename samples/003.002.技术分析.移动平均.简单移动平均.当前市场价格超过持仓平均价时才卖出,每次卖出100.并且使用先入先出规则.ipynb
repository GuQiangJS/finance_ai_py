# %% [markdown]
# https://zh.wikipedia.org/wiki/%E7%A7%BB%E5%8B%95%E5%B9%B3%E5%9D%87
#
# [报告](#%E6%8A%A5%E5%91%8A)

# %%
import warnings
warnings.filterwarnings('ignore')
import QUANTAXIS as QA
import talib
import jupyter_helper
import numpy as np
from pyecharts import Line

import os
os.path.abspath(os.path.dirname(os.getcwd()))
import sys
sys.path.append(os.path.abspath(os.path.dirname(os.getcwd())))

from finance_ai_py import quantaxis_ext
# Out:
# C:\Users\GuQiang\AppData\Local\conda\conda\envs\finance35\lib\site-packages\empyrical\utils.py:32: UserWarning: Unable to import pandas_datareader. Suppressing import error and continuing. All data reading functionality will raise errors; but has been deprecated and will be removed in a later version.
#   warnings.warn(msg)

# %%
s,e=jupyter_helper.get_start_end_date()
benchmark_code=jupyter_helper.get_benchmark_code()
stock_code='600436'
timeperiod=5
nbdevup=2
nbdevdn=2
INIT_CASH=10000
MATYPE=MA_Type.SMA

# %%
stock_data=QA.QA_fetch_stock_day_adv(stock_code,s,e)

# %%
from talib import MA_Type
df=stock_data.data
df['qfq_close']=stock_data.to_qfq().data['close']
df=df.reset_index().set_index('date')
df['DAILY_RETURN']=np.round(jupyter_helper.calc_daily_return(df['close']),4)
df['SMA_UPPER'],df['SMA_MIDDLE'],df['SMA_LOWER']=talib.BBANDS(np.array(df['qfq_close']), timeperiod=timeperiod, nbdevup=nbdevup, nbdevdn=nbdevdn,matype=MATYPE)
df=df.dropna()

# %%
df
# Out:
#               code   open   high    low  close   volume       amount  \
# date
# 2005-01-10  600436  11.39  11.46  11.35  11.40   1544.0    1762106.0
# 2005-01-11  600436  11.40  11.48  11.31  11.48   2179.0    2488290.0
# 2005-01-12  600436  11.48  11.48  11.36  11.42   1910.0    2180402.0
# 2005-01-13  600436  11.41  11.45  11.20  11.26   3609.0    4080836.0
# 2005-01-14  600436  11.24  11.40  11.21  11.25   2494.0    2808243.0
# 2005-01-17  600436  11.13  11.36  11.10  11.19   2491.0    2786137.0
# 2005-01-18  600436  11.20  11.40  11.18  11.37   2798.0    3160824.0
# 2005-01-19  600436  11.36  11.36  11.20  11.22   1426.0    1602674.0
# 2005-01-20  600436  11.18  11.22  11.08  11.18   3354.0    3731700.0
# 2005-01-21  600436  11.10  11.37  10.95  11.34   6487.0    7207665.0
# 2005-01-25  600436  11.49  11.72  11.30  11.70   6365.0    7327900.0
# 2005-01-26  600436  11.65  11.70  11.50  11.56   2099.0    2439923.0
# 2005-01-27  600436  11.50  11.60  11.44  11.51   1175.0    1356029.0
# 2005-01-28  600436  11.40  11.51  11.35  11.49   1579.0    1805004.0
# 2005-01-31  600436  11.32  11.63  11.32  11.46   2320.0    2661155.0
# 2005-02-01  600436  11.55  11.58  11.36  11.38   1455.0    1664551.0
# 2005-02-02  600436  11.30  11.89  11.30  11.87   3654.0    4270490.0
# 2005-02-03  600436  11.90  11.90  11.62  11.68   2679.0    3146621.0
# 2005-02-04  600436  11.68  12.07  11.58  12.02   5389.0    6428419.0
# 2018-12-26  86.420000       -0.0108  88.473619   85.974000  83.474381
# 2018-12-27  86.950000        0.0061  88.776201   86.154000  83.531799
# 2018-12-28  86.650000       -0.0035  87.477044   86.758000  86.038956
# 2019-01-02  84.390000       -0.0261  88.416333   86.354000  84.291667
# 2019-01-03  80.990000       -0.0403  89.548700   85.080000  80.611300
# 2019-01-04  82.680000        0.0209  88.903956   84.332000  79.760044
# 2019-01-07  83.390000        0.0086  87.375231   83.620000  79.864769
# 2019-01-08  83.500000        0.0013  85.266172   82.990000  80.713828
# 2019-01-09  85.200000        0.0204  85.875098   83.152000  80.428902
# 2019-01-10  84.600000       -0.0070  85.681788   83.874000  82.066212
# 2019-01-11  85.150000        0.0065  85.934520   84.368000  82.801480
# 2019-01-14  84.600000       -0.0065  85.833765   84.610000  83.386235
# 2019-01-15  87.200000        0.0307  87.270417   85.350000  83.429583
# 2019-01-16  88.000000        0.0092  88.744361   85.910000  83.075639
# 2019-01-17  86.000000       -0.0227  88.710635   86.190000  83.669365
# 2019-01-18  90.580000        0.0533  91.299483   87.276000  83.252517
# 2019-01-21  90.320000       -0.0029  91.974918   88.420000  84.865082
# 2019-01-22  88.360000       -0.0217  92.003761   88.652000  85.300239
# 2019-01-23  88.600000        0.0027  92.064231   88.772000  85.479769
# 2019-01-24  87.990000       -0.0069  91.302416   89.170000  87.037584
#
# [3358 rows x 12 columns]

# %% [markdown]
# ## 按照PSI<30(买入)，PSI>70(卖出)绘制日线（前复权）

# %%
line = Line('')
markpoint_b=[]
markpoint_s=[]
for x in df[df['qfq_close']<df['SMA_LOWER']].index:
    markpoint_b.append({"coord":[x.date(),np.round(df.loc[x]['qfq_close'],2)],'name':'buy-{}'.format(x.date())})
for x in df[df['qfq_close']>df['SMA_UPPER']].index:
    markpoint_s.append({"coord":[x.date(),np.round(df.loc[x]['qfq_close'],2)],'name':'sale-{}'.format(x.date())})
# 通过使用同一日线数据但是根据买入/卖出分别绘制的方式，实现不同颜色标记买入和卖出点
line.add('qfq_close_b', df.index.date, np.round(df['qfq_close'], 2),datazoom_extra_type='both',
                 is_datazoom_extra_show=True,
                 datazoom_extra_orient='horizontal',
        mark_point=markpoint_b)
line.add('qfq_close_s', df.index.date, np.round(df['qfq_close'], 2),datazoom_extra_type='both',
                 is_datazoom_extra_show=True,
                 datazoom_extra_orient='horizontal',
        mark_point=markpoint_s)
line.add('SMA_LOWER', df.index.date, np.round(df['SMA_LOWER'], 2),datazoom_extra_type='both',
                 is_datazoom_extra_show=True,
                 datazoom_extra_orient='horizontal')
line.add('SMA_UPPER', df.index.date, np.round(df['SMA_UPPER'], 2),datazoom_extra_type='both',
                 is_datazoom_extra_show=True,
                 datazoom_extra_orient='horizontal')
line.add('SMA_MIDDLE', df.index.date, np.round(df['SMA_MIDDLE'], 2),datazoom_extra_type='both',
                 is_datazoom_extra_show=True,
                 datazoom_extra_orient='horizontal')
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="aa595c95eb7f4b649d5965546f3ed02f" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_aa595c95eb7f4b649d5965546f3ed02f = echarts.init(document.getElementById('aa595c95eb7f4b649d5965546f3ed02f'), 'light', {renderer: 'canvas'});
#
# var option_aa595c95eb7f4b649d5965546f3ed02f = {
#     "series": [
#         {
#             "type": "line",
#             "showSymbol": true,
#             "seriesId": 8763359,
#             "lineStyle": {
#                 "normal": {
#                     "curveness": 0,
#                     "width": 1,
#                     "opacity": 1,
#                     "type": "solid"
#                 }
#             },
#             "label": {
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "normal": {
#                     "show": false,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top"
#                 }
#             },
#             "smooth": false,
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "symbolSize": 4,
#             "name": "qfq_close_b",
#             "data": [
#                 [
#                     "2005-01-10",
#                     1.83
#                 ],
#                 [
#                     "2005-01-11",
#                     1.84
#                 ],
#                 [
#                     "2005-01-12",
#                     1.83
#                 ],
#                 [
#                     "2005-01-13",
#                     1.81
#                 ],
#                 [
#                     "2005-01-14",
#                     1.81
#                 ],
#                 [
#                     "2005-01-17",
#                     1.8
#                 ],
#                 [
#                     "2005-01-18",
#                     1.83
#                 ],
#                 [
#                     "2005-01-19",
#                     1.8
#                 ],
#                 [
#                     "2005-01-20",
#                     1.8
#                 ],
#                 [
#                     "2005-01-21",
#                     1.82
#                 ],
#                 [
#                     "2005-01-25",
#                     1.88
#                 ],
#                 [
#                     "2005-01-26",
#                     1.86
#                 ],
#                 [
#                     "2005-01-27",
#                     1.85
#                 ],
#                 [
#                     "2005-01-28",
#                     1.85
#                 ],
#                 [
#                     "2005-01-31",
#                     1.84
#                 ],
#                 [
#                     "2005-02-01",
#                     1.83
#                 ],
#                 [
#                     "2005-02-02",
#                     1.91
#                 ],
#                 [
#                     "2005-02-03",
#                     1.88
#                 ],
#                 [
#                     "2005-02-04",
#                     1.93
#                 ],
#                 [
#                     "2005-02-16",
#                     1.95
#                 ],
#                 [
#                     "2005-02-17",
#                     1.96
#                 ],
#                 [
#                     "2005-02-18",
#                     1.98
#                 ],
#                 [
#                     "2005-02-21",
#                     2.04
#                 ],
#                 [
#                     "2005-02-22",
#                     2.09
#                 ],
#                 [
#                     "2005-02-23",
#                     2.08
#                 ],
#                 [
#                     "2005-02-24",
#                     2.07
#                 ],
#                 [
#                     "2005-02-25",
#                     2.1
#                 ],
#                 [
#                     "2005-02-28",
#                     2.04
#                 ],
#                 [
#                     "2005-03-01",
#                     2.06
#                 ],
#                 [
#                     "2005-03-02",
#                     2.02
#                 ],
#                 [
#                     "2005-03-03",
#                     2.01
#                 ],
#                 [
#                     "2005-03-04",
#                     2.02
#                 ],
#                 [
#                     "2005-03-07",
#                     2.03
#                 ],
#                 [
#                     "2005-03-08",
#                     2.13
#                 ],
#                 [
#                     "2005-03-09",
#                     2.13
#                 ],
#                 [
#                     "2005-03-10",
#                     2.08
#                 ],
#                 [
#                     "2005-03-11",
#                     2.1
#                 ],
#                 [
#                     "2005-03-14",
#                     2.18
#                 ],
#                 [
#                     "2005-03-15",
#                     2.18
#                 ],
#                 [
#                     "2005-03-16",
#                     2.11
#                 ],
#                 [
#                     "2005-03-17",
#                     2.17
#                 ],
#                 [
#                     "2005-03-18",
#                     2.05
#                 ],
#                 [
#                     "2005-03-21",
#                     2.13
#                 ],
#                 [
#                     "2005-03-22",
#                     2.18
#                 ],
#                 [
#                     "2005-03-23",
#                     2.1
#                 ],
#                 [
#                     "2005-03-24",
#                     2.05
#                 ],
#                 [
#                     "2005-03-25",
#                     2.02
#                 ],
#                 [
#                     "2005-03-28",
#                     1.95
#                 ],
#                 [
#                     "2005-03-29",
#                     1.93
#                 ],
#                 [
#                     "2005-03-30",
#                     1.9
#                 ],
#                 [
#                     "2005-03-31",
#                     1.95
#                 ],
#                 [
#                     "2005-04-01",
#                     2.0
#                 ],
#                 [
#                     "2005-04-04",
#                     1.96
#                 ],
#                 [
#                     "2005-04-05",
#                     2.03
#                 ],
#                 [
#                     "2005-04-06",
#                     2.09
#                 ],
#                 [
#                     "2005-04-07",
#                     2.08
#                 ],
#                 [
#                     "2005-04-08",
#                     2.12
#                 ],
#                 [
#                     "2005-04-11",
#                     2.17
#                 ],
#                 [
#                     "2005-04-12",
#                     2.17
#                 ],
#                 [
#                     "2005-04-13",
#                     2.2
#                 ],
#                 [
#                     "2005-04-14",
#                     2.18
#                 ],
#                 [
#                     "2005-04-15",
#                     2.17
#                 ],
#                 [
#                     "2005-04-18",
#                     2.17
#                 ],
#                 [
#                     "2005-04-19",
#                     2.18
#                 ],
#                 [
#                     "2005-04-20",
#                     2.2
#                 ],
#                 [
#                     "2005-04-21",
#                     2.4
#                 ],
#                 [
#                     "2005-04-22",
#                     2.36
#                 ],
#                 [
#                     "2005-04-25",
#                     2.45
#                 ],
#                 [

# %% [markdown]
# ## 模拟下单

# %%
stock_account=quantaxis_ext.QA_Account_Ext(init_cash=INIT_CASH)
amount=100
Broker = QA.QA_BacktestBroker()

for index in df.index:
    if df.loc[index]['qfq_close']<df.loc[index]['SMA_LOWER']:
        order = stock_account.send_order(
                    code=stock_code,
                    time=index.date(),
                    amount=amount,
                    towards=QA.ORDER_DIRECTION.BUY,
                    price=0,
                    order_model=QA.ORDER_MODEL.CLOSE,
                    amount_model=QA.AMOUNT_MODEL.BY_AMOUNT  # 按数量下单
                    # 在按金额下单的时候,应给予 money参数
                    # 在按数量下单的时候,应给予 amount参数
                )
                # print(item.to_json()[0])
        Broker.receive_order(QA.QA_Event(order=order))

        trade_mes = Broker.query_orders(stock_account.account_cookie, 'filled')
        res = trade_mes.loc[order.account_cookie, order.realorder_id]
        order.trade(res.trade_id, res.trade_price, res.trade_amount,res.trade_time) 
    elif df.loc[index]['qfq_close']<df.loc[index]['SMA_UPPER']:
#         if stock_account.sell_available.get(stock_code, 0) >= amount:#当前有可卖的数量时
        if stock_account.sell_available.get(stock_code, 0) >= amount and df.loc[index]['qfq_close']>stock_account.hold_price_fifo().at[stock_code][0]:
            order = stock_account.send_order(
                        code=stock_code,
                        time=index.date(),
                        amount=amount,
#                         amount=stock_account.sell_available.get(stock_code, 0),
                        towards=QA.ORDER_DIRECTION.SELL,
                        price=0,
                        order_model=QA.ORDER_MODEL.CLOSE,
                        amount_model=QA.AMOUNT_MODEL.BY_AMOUNT  # 按数量下单
                        # 在按金额下单的时候,应给予 money参数
                        # 在按数量下单的时候,应给予 amount参数
                    )
                    # print(item.to_json()[0])
            Broker.receive_order(QA.QA_Event(order=order))

            trade_mes = Broker.query_orders(stock_account.account_cookie, 'filled')
            res = trade_mes.loc[order.account_cookie, order.realorder_id]
            order.trade(res.trade_id, res.trade_price, res.trade_amount,res.trade_time)
    stock_account.settle()

# %%
stock_account.history_table
# Out:
# Empty DataFrame
# Columns: [datetime, code, price, amount, cash, order_id, realorder_id, trade_id, account_cookie, commission, tax, message, frozen]
# Index: []

# %%
stock_account.history_table.iloc[stock_account.history_table[stock_account.history_table['amount']<0].tail(1).index.values[0]+1:]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-33-43a56ee64271> in <module>
# ----> 1 stock_account.history_table.iloc[stock_account.history_table[stock_account.history_table['amount']<0].tail(1).index.values[0]+1:]
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
stock_account.hold_table()
# Out:
# Series([], Name: amount, dtype: float64)

# %% [markdown]
# ## 当前持仓股票（包含买入时间，买入价格等）

# %%
stock_account.hold_table_fifo()
# Out:
# Empty DataFrame
# Columns: [code, amount, price]
# Index: []

# %% [markdown]
# ## 当前账户剩余资金

# %%
stock_account.cash_available
# Out:
# 10000

# %% [markdown]
# ## 持仓成本

# %%
stock_account.hold_price()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## 持仓成本（不计算已卖出的交易的成本）

# %%
stock_account.hold_price_fifo()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
e-stock_account.hold_table_fifo().index
# Out:
# TimedeltaIndex([], dtype='timedelta64[ns]', name='date', freq=None)

# %%
e
# Out:
# Timestamp('2019-01-24 00:00:00')

# %% [markdown]
# ## 报告

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" 

'以 {0} 作为测试对象。初始资金 {1}。每次交易 {2} 股。'.format(stock_code,INIT_CASH,amount)
'按照 {0} 规则进行交易。'.format(MATYPE)
'卖出时只有当前市场价格超过持仓平均价时才卖出。并且使用先入先出规则。'
'总交易次数 {0} 次。'.format(stock_account.history_table.shape[0])
'当前持仓均价：{0}，持仓数量：{1}。 当前持仓最大天数：{2} 当前持有现金：{3}'.format(
    np.round(stock_account.hold_price_fifo()[stock_code][0],4),
    stock_account.hold_price_fifo()[stock_code][1],
e-stock_account.hold_table_fifo().index[0],
np.round(stock_account.cash_available,4))
# Out:
# '以 600436 作为测试对象。初始资金 10000。每次交易 100 股。'
# '按照 0 规则进行交易。'
# '卖出时只有当前市场价格超过持仓平均价时才卖出。并且使用先入先出规则。'
# '总交易次数 0 次。'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\conda\conda\envs\finance35\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '600436'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-bf1179c0507d> in <module>
#       7 '总交易次数 {0} 次。'.format(stock_account.history_table.shape[0])
#       8 '当前持仓均价：{0}，持仓数量：{1}。 当前持仓最大天数：{2} 当前持有现金：{3}'.format(
# ----> 9     np.round(stock_account.hold_price_fifo()[stock_code][0],4),
#      10     stock_account.hold_price_fifo()[stock_code][1],
#      11 e-stock_account.hold_table_fifo().index[0],
#
# ~\AppData\Local\conda\conda\envs\finance35\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\AppData\Local\conda\conda\envs\finance35\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\AppData\Local\conda\conda\envs\finance35\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\AppData\Local\conda\conda\envs\finance35\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\AppData\Local\conda\conda\envs\finance35\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '600436'
