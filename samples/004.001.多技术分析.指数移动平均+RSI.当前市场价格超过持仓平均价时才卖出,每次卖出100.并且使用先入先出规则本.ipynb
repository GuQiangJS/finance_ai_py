# %% [markdown]
# https://zh.wikipedia.org/wiki/%E7%A7%BB%E5%8B%95%E5%B9%B3%E5%9D%87
#
# [报告](#%E6%8A%A5%E5%91%8A)

# %%
import warnings
warnings.filterwarnings('ignore')
import QUANTAXIS as QA
import talib
import jupyter_helper
import numpy as np
from pyecharts import Line

import os
os.path.abspath(os.path.dirname(os.getcwd()))
import sys
sys.path.append(os.path.abspath(os.path.dirname(os.getcwd())))

from finance_ai_py import quantaxis_ext
from talib import MA_Type
# Out:
# C:\Users\GuQiang\AppData\Local\conda\conda\envs\finance35\lib\site-packages\empyrical\utils.py:32: UserWarning: Unable to import pandas_datareader. Suppressing import error and continuing. All data reading functionality will raise errors; but has been deprecated and will be removed in a later version.
#   warnings.warn(msg)

# %%
s,e=jupyter_helper.get_start_end_date()
benchmark_code=jupyter_helper.get_benchmark_code()
stock_code='600436'
timeperiod=5
nbdevup=2
nbdevdn=2
INIT_CASH=10000
UP=70
LOW=30
MATYPE=MA_Type.EMA

# %%
stock_data=QA.QA_fetch_stock_day_adv(stock_code,s,e)

# %%
from talib import MA_Type
df=stock_data.data
df['qfq_close']=stock_data.to_qfq().data['close']
df=df.reset_index().set_index('date')
df['DAILY_RETURN']=np.round(jupyter_helper.calc_daily_return(df['close']),4)
df['MA_UPPER'],df['MA_MIDDLE'],df['MA_LOWER']=talib.BBANDS(np.array(df['qfq_close']), timeperiod=timeperiod, nbdevup=nbdevup, nbdevdn=nbdevdn,matype=MATYPE)
df['RSI']=talib.RSI(np.array(df['qfq_close']))
df=df.dropna()

# %%
df
# Out:
#               code   open   high    low  close   volume       amount  \
# date
# 2005-01-25  600436  11.49  11.72  11.30  11.70   6365.0    7327900.0
# 2005-01-26  600436  11.65  11.70  11.50  11.56   2099.0    2439923.0
# 2005-01-27  600436  11.50  11.60  11.44  11.51   1175.0    1356029.0
# 2005-01-28  600436  11.40  11.51  11.35  11.49   1579.0    1805004.0
# 2005-01-31  600436  11.32  11.63  11.32  11.46   2320.0    2661155.0
# 2005-02-01  600436  11.55  11.58  11.36  11.38   1455.0    1664551.0
# 2005-02-02  600436  11.30  11.89  11.30  11.87   3654.0    4270490.0
# 2005-02-03  600436  11.90  11.90  11.62  11.68   2679.0    3146621.0
# 2005-02-04  600436  11.68  12.07  11.58  12.02   5389.0    6428419.0
# 2005-02-16  600436  12.04  12.40  12.04  12.11   3752.0    4576814.0
# 2005-02-17  600436  11.97  12.28  11.90  12.18   1914.0    2317955.0
# 2005-02-18  600436  12.15  12.30  12.12  12.30   4688.0    5738922.0
# 2005-02-21  600436  12.30  12.78  12.30  12.72  10385.0   13125683.0
# 2005-02-22  600436  12.72  13.04  12.60  13.01  17878.0   23070556.0
# 2005-02-23  600436  12.99  13.15  12.71  12.95   6522.0    8443091.0
# 2005-02-24  600436  12.93  12.98  12.81  12.89   3980.0    5137831.0
# 2005-02-25  600436  12.89  13.17  12.89  13.05   5521.0    7220761.0
# 2019-01-09  49.972209
# 2019-01-10  48.492227
# 2019-01-11  49.955353
# 2019-01-14  48.472530
# 2019-01-15  55.236838
# 2019-01-16  57.102849
# 2019-01-17  51.340753
# 2019-01-18  61.036850
# 2019-01-21  60.302238
# 2019-01-22  54.934650
# 2019-01-23  55.457480
# 2019-01-24  53.750595
#
# [3348 rows x 13 columns]

# %% [markdown]
# ## 绘制日线（前复权）

# %%
line = Line('')
markpoint_b=[]
markpoint_s=[]
for x in df[(df['qfq_close']<df['MA_LOWER']) & (df['RSI']<LOW)].index:
    markpoint_b.append({"coord":[x.date(),np.round(df.loc[x]['qfq_close'],2)],'name':'buy-{}'.format(x.date())})
for x in df[(df['qfq_close']>df['MA_UPPER']) & (df['RSI']>UP)].index:
    markpoint_s.append({"coord":[x.date(),np.round(df.loc[x]['qfq_close'],2)],'name':'sale-{}'.format(x.date())})
# 通过使用同一日线数据但是根据买入/卖出分别绘制的方式，实现不同颜色标记买入和卖出点
line.add('qfq_close_b', df.index.date, np.round(df['qfq_close'], 2),datazoom_extra_type='both',
                 is_datazoom_extra_show=True,
                 datazoom_extra_orient='horizontal',
        mark_point=markpoint_b)
line.add('qfq_close_s', df.index.date, np.round(df['qfq_close'], 2),datazoom_extra_type='both',
                 is_datazoom_extra_show=True,
                 datazoom_extra_orient='horizontal',
        mark_point=markpoint_s)
line.add('MA_LOWER', df.index.date, np.round(df['MA_LOWER'], 2),datazoom_extra_type='both',
                 is_datazoom_extra_show=True,
                 datazoom_extra_orient='horizontal')
line.add('MA_UPPER', df.index.date, np.round(df['MA_UPPER'], 2),datazoom_extra_type='both',
                 is_datazoom_extra_show=True,
                 datazoom_extra_orient='horizontal')
line.add('MA_MIDDLE', df.index.date, np.round(df['MA_MIDDLE'], 2),datazoom_extra_type='both',
                 is_datazoom_extra_show=True,
                 datazoom_extra_orient='horizontal')
line
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="6ae3275f85c6453ba45aec48a2f8817b" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_6ae3275f85c6453ba45aec48a2f8817b = echarts.init(document.getElementById('6ae3275f85c6453ba45aec48a2f8817b'), 'light', {renderer: 'canvas'});
#
# var option_6ae3275f85c6453ba45aec48a2f8817b = {
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "legend": [
#         {
#             "data": [
#                 "qfq_close_b",
#                 "qfq_close_s",
#                 "MA_LOWER",
#                 "MA_UPPER",
#                 "MA_MIDDLE"
#             ],
#             "orient": "horizontal",
#             "show": true,
#             "selectedMode": "multiple",
#             "top": "top",
#             "left": "center",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "splitLine": {
#                 "show": true
#             },
#             "type": "value",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "show": true,
#             "inverse": false,
#             "boundaryGap": true,
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "margin": 8,
#                 "formatter": "{value} ",
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "interval": "auto",
#                 "rotate": 0
#             },
#             "nameLocation": "middle"
#         }
#     ],
#     "series": [
#         {
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "position": "top",
#                     "show": false
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 }
#             },
#             "symbolSize": 4,
#             "data": [
#                 [
#                     "2005-01-25",
#                     1.88
#                 ],
#                 [
#                     "2005-01-26",
#                     1.86
#                 ],
#                 [
#                     "2005-01-27",
#                     1.85
#                 ],
#                 [
#                     "2005-01-28",
#                     1.85
#                 ],
#                 [
#                     "2005-01-31",
#                     1.84
#                 ],
#                 [
#                     "2005-02-01",
#                     1.83
#                 ],
#                 [
#                     "2005-02-02",
#                     1.91
#                 ],
#                 [
#                     "2005-02-03",
#                     1.88
#                 ],
#                 [
#                     "2005-02-04",
#                     1.93
#                 ],
#                 [
#                     "2005-02-16",
#                     1.95
#                 ],
#                 [
#                     "2005-02-17",
#                     1.96
#                 ],
#                 [
#                     "2005-02-18",
#                     1.98
#                 ],
#                 [
#                     "2005-02-21",
#                     2.04
#                 ],
#                 [
#                     "2005-02-22",
#                     2.09
#                 ],
#                 [
#                     "2005-02-23",
#                     2.08
#                 ],
#                 [
#                     "2005-02-24",
#                     2.07
#                 ],
#                 [
#                     "2005-02-25",
#                     2.1
#                 ],
#                 [
#                     "2005-02-28",
#                     2.04
#                 ],
#                 [
#                     "2005-03-01",
#                     2.06
#                 ],
#                 [
#                     "2005-03-02",
#                     2.02
#                 ],
#                 [
#                     "2005-03-03",
#                     2.01
#                 ],
#                 [
#                     "2005-03-04",
#                     2.02
#                 ],
#                 [
#                     "2005-03-07",
#                     2.03
#                 ],
#                 [
#                     "2005-03-08",
#                     2.13
#                 ],
#                 [
#                     "2005-03-09",
#                     2.13
#                 ],
#                 [
#                     "2005-03-10",
#                     2.08
#                 ],
#                 [
#                     "2005-03-11",
#                     2.1
#                 ],
#                 [
#                     "2005-03-14",
#                     2.18
#                 ],
#                 [
#                     "2005-03-15",
#                     2.18
#                 ],
#                 [
#                     "2005-03-16",
#                     2.11
#                 ],
#                 [
#                     "2005-03-17",
#                     2.17
#                 ],
#                 [
#                     "2005-03-18",
#                     2.05
#                 ],
#                 [
#                     "2005-03-21",
#                     2.13
#                 ],
#                 [
#                     "2005-03-22",
#                     2.18
#                 ],
#                 [
#                     "2005-03-23",
#                     2.1
#                 ],
#                 [
#                     "2005-03-24",
#                     2.05
#                 ],
#                 [
#                     "2005-03-25",
#                     2.02
#                 ],
#                 [
#                     "2005-03-28",
#                     1.95
#                 ],
#                 [
#                     "2005-03-29",
#                     1.93
#                 ],
#                 [
#                     "2005-03-30",
#                     1.9
#                 ],
#                 [
#                     "2005-03-31",
#                     1.95
#                 ],
#                 [
#                     "2005-04-01",
#                     2.0
#                 ],
#                 [
#                     "2005-04-04",
#                     1.96
#                 ],
#                 [
#                     "2005-04-05",
#                     2.03
#                 ],
#                 [
#                     "2005-04-06",
#                     2.09
#                 ],
#                 [
#                     "2005-04-07",
#                     2.08
#                 ],
#                 [
#                     "2005-04-08",
#                     2.12
#                 ],
#                 [
#                     "2005-04-11",
#                     2.17
#                 ],
#                 [
#                     "2005-04-12",
#                     2.17
#                 ],
#                 [
#                     "2005-04-13",
#                     2.2
#                 ],
#                 [
#                     "2005-04-14",
#                     2.18
#                 ],
#                 [
#                     "2005-04-15",
#                     2.17
#                 ],
#                 [
#                     "2005-04-18",
#                     2.17
#                 ],
#                 [
#                     "2005-04-19",
#                     2.18
#                 ],
#                 [

# %% [markdown]
# ## 模拟下单

# %%
stock_account=quantaxis_ext.QA_Account_Ext(init_cash=INIT_CASH)
amount=100
Broker = QA.QA_BacktestBroker()

for index in df.index:
    if df.loc[index]['qfq_close']<df.loc[index]['MA_LOWER'] and df.loc[index]['RSI']<LOW:
        order = stock_account.send_order(
                    code=stock_code,
                    time=index.date(),
                    amount=amount,
                    towards=QA.ORDER_DIRECTION.BUY,
                    price=0,
                    order_model=QA.ORDER_MODEL.CLOSE,
                    amount_model=QA.AMOUNT_MODEL.BY_AMOUNT  # 按数量下单
                    # 在按金额下单的时候,应给予 money参数
                    # 在按数量下单的时候,应给予 amount参数
                )
                # print(item.to_json()[0])
        Broker.receive_order(QA.QA_Event(order=order))

        trade_mes = Broker.query_orders(stock_account.account_cookie, 'filled')
        res = trade_mes.loc[order.account_cookie, order.realorder_id]
        order.trade(res.trade_id, res.trade_price, res.trade_amount,res.trade_time) 
    elif df.loc[index]['qfq_close']>df.loc[index]['MA_UPPER'] and df.loc[index]['RSI']>UP:
#         if stock_account.sell_available.get(stock_code, 0) >= amount:#当前有可卖的数量时
        if stock_account.sell_available.get(stock_code, 0) >= amount and df.loc[index]['qfq_close']>stock_account.hold_price_fifo().at[stock_code][0]:
            order = stock_account.send_order(
                        code=stock_code,
                        time=index.date(),
                        amount=amount,
#                         amount=stock_account.sell_available.get(stock_code, 0),
                        towards=QA.ORDER_DIRECTION.SELL,
                        price=0,
                        order_model=QA.ORDER_MODEL.CLOSE,
                        amount_model=QA.AMOUNT_MODEL.BY_AMOUNT  # 按数量下单
                        # 在按金额下单的时候,应给予 money参数
                        # 在按数量下单的时候,应给予 amount参数
                    )
                    # print(item.to_json()[0])
            Broker.receive_order(QA.QA_Event(order=order))

            trade_mes = Broker.query_orders(stock_account.account_cookie, 'filled')
            res = trade_mes.loc[order.account_cookie, order.realorder_id]
            order.trade(res.trade_id, res.trade_price, res.trade_amount,res.trade_time)
    stock_account.settle()
# Out:
# < QA_Order realorder_id Order_TWvaGYNL datetime:2010-07-08 15:00:00 code:600436 amount:100 price:34.6 towards:1 btype:stock_cn order_id:Order_TWvaGYNL account:Acc_bR2gF38u status:queued >
# receive deal
# < QA_Order realorder_id Order_dj9WSPUk datetime:2011-01-17 15:00:00 code:600436 amount:100 price:60.71 towards:1 btype:stock_cn order_id:Order_dj9WSPUk account:Acc_bR2gF38u status:queued >
# receive deal
# < QA_Order realorder_id Order_0so5jPNw datetime:2013-11-04 15:00:00 code:600436 amount:100 price:101.17 towards:1 btype:stock_cn order_id:Order_0so5jPNw account:Acc_bR2gF38u status:queued >
# receive deal
# < QA_Order realorder_id Order_rpI5amjl datetime:2017-10-27 15:00:00 code:600436 amount:100 price:66.02 towards:-1 btype:stock_cn order_id:Order_rpI5amjl account:Acc_bR2gF38u status:queued >
# receive deal
# < QA_Order realorder_id Order_4RrcOXa2 datetime:2018-03-26 15:00:00 code:600436 amount:100 price:86.32 towards:-1 btype:stock_cn order_id:Order_4RrcOXa2 account:Acc_bR2gF38u status:queued >
# receive deal

# %%
stock_account.history_table
# Out:
#               datetime    code  price  amount       cash        order_id  \
# 0  2010-07-08 00:00:00  600436  34.60     100   6535.000  Order_TWvaGYNL
# 1  2011-01-17 00:00:00  600436  60.71     100    459.000  Order_dj9WSPUk
# 2  2017-10-27 00:00:00  600436  66.02    -100   7049.398  Order_rpI5amjl
# 3  2018-03-26 00:00:00  600436  86.32    -100  15667.766  Order_4RrcOXa2
#
#      realorder_id        trade_id account_cookie  commission    tax message  \
# 0  Order_TWvaGYNL  Trade_ouKJYiO4   Acc_bR2gF38u           5  0.000    None
# 1  Order_dj9WSPUk  Trade_zPgW8xY5   Acc_bR2gF38u           5  0.000    None
# 2  Order_rpI5amjl  Trade_Hs7P5QF6   Acc_bR2gF38u           5  6.602    None
# 3  Order_4RrcOXa2  Trade_nxpSEeF3   Acc_bR2gF38u           5  8.632    None
#
#    frozen
# 0       0
# 1       0
# 2       0
# 3       0

# %%
stock_account.history_table.iloc[stock_account.history_table[stock_account.history_table['amount']<0].tail(1).index.values[0]+1:]
# Out:
# Empty DataFrame
# Columns: [datetime, code, price, amount, cash, order_id, realorder_id, trade_id, account_cookie, commission, tax, message, frozen]
# Index: []

# %%
stock_account.hold_table()
# Out:
# Series([], Name: amount, dtype: object)

# %% [markdown]
# ## 当前持仓股票（包含买入时间，买入价格等）

# %%
stock_account.hold_table_fifo()
# Out:
# Empty DataFrame
# Columns: [code, amount, price]
# Index: []

# %% [markdown]
# ## 当前账户剩余资金

# %%
stock_account.cash_available
# Out:
# 29179.241

# %% [markdown]
# ## 持仓成本

# %%
stock_account.hold_price()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# ## 持仓成本（不计算已卖出的交易的成本）

# %%
stock_account.hold_price_fifo()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
e-stock_account.hold_table_fifo().index
# Out:
# TimedeltaIndex([], dtype='timedelta64[ns]', name='date', freq=None)

# %%
e
# Out:
# Timestamp('2019-01-24 00:00:00')

# %% [markdown]
# ## 报告

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all" 

'以 {0} 作为测试对象。初始资金 {1}。每次交易 {2} 股。'.format(stock_code,INIT_CASH,amount)
'按照 {} + RSI< {} -买入，RSI> {} -卖出 规则进行交易。'.format(MATYPE,LOW,UP)
'卖出时只有当前市场价格超过持仓平均价时才卖出。并且使用先入先出规则。'
'总交易次数 {0} 次。'.format(stock_account.history_table.shape[0])
if not stock_account.hold_price_fifo().empty:
    '当前持仓均价：{0}，持仓数量：{1}。 当前持仓最大天数：{2} 当前持有现金：{3}'.format(
        np.round(stock_account.hold_price_fifo()[stock_code][0],4),
        stock_account.hold_price_fifo()[stock_code][1],
    e-stock_account.hold_table_fifo().index[0],
    np.round(stock_account.cash_available,4))
else:
    '当前无持仓。当前持有现金：{}'.format(np.round(stock_account.cash_available,4))
# Out:
# '以 600436 作为测试对象。初始资金 10000。每次交易 100 股。'
# '按照 1 + RSI< 30 -买入，RSI> 70 -卖出 规则进行交易。'
# '卖出时只有当前市场价格超过持仓平均价时才卖出。并且使用先入先出规则。'
# '总交易次数 4 次。'
# '当前无持仓。当前持有现金：15667.766'
