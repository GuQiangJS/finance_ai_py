# %%
import warnings
warnings.filterwarnings('ignore')
import jupyter_helper
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score # K折交叉验证模块
from sklearn.preprocessing import MinMaxScaler

import QUANTAXIS as QA
import pandas as pd
import numpy as np
import pyecharts
# Out:
# C:\Users\GuQiang\AppData\Local\conda\conda\envs\finance35\lib\site-packages\empyrical\utils.py:32: UserWarning: Unable to import pandas_datareader. Suppressing import error and continuing. All data reading functionality will raise errors; but has been deprecated and will be removed in a later version.
#   warnings.warn(msg)

# %%
s,e=jupyter_helper.get_start_end_date()
benchmark_code=jupyter_helper.get_benchmark_code()
stock_code='300378'
DAYS=5#计算时间段

# %%
def create_validate_df_close(df: pd.DataFrame,
                             days: int,
                             column: str = 'close') -> pd.DataFrame:
    """制作验证用数据。

    根据 df[column].shift(-days)` 查找指定天数后的指定列的数据作为验证数据。

    Args:
        df: 数据源
        days: 天数
        column: 使用的列
    """
    if column not in df.columns:
        raise ValueError('数据中不包含 {} 列。'.format(column))
    return pd.DataFrame(df[column].shift(-1 * days).values,
                        columns=[days],
                        index=df.index).dropna()


def get_calc_data(stock_code, s, e, fq='qfq',
                   drop_columns=['code', 'preclose', 'adj'],
                   scaler=['amount', 'volume'],
                   scaler_func=MinMaxScaler):
    """获取计算用数据源

    Args:
        fq: 是否采用复权数据。默认使用前复权。如果不需要复权则传''即可。
        stock_code:
        s:
        e:
        drop_columns: 丢弃的列
        scaler: 需要做归一化的数据列。
        scaler_func: 做归一化时默认使用的方法。
    """
    raw_data = QA.QA_fetch_stock_day_adv(stock_code, s, e)
    calc_data = raw_data.data.reset_index().set_index(
        'date').copy()
    if fq == 'qfq':
        qfq_data = raw_data.to_qfq().data.reset_index().set_index(
            'date')  # DataFrame格式
        calc_data = qfq_data.copy()
    elif fq == 'hfq':
        qfq_data = raw_data.to_qfq().data.reset_index().set_index(
            'date')  # DataFrame格式
        calc_data = qfq_data.copy()
    if drop_columns:
        calc_data = calc_data.drop(columns=drop_columns)  # 丢弃多余的列
    if scaler:
        calc_data[scaler] = scaler_func().fit_transform(
            calc_data[scaler])
    return calc_data

def packing_calc_data(df:pd.DataFrame,stock_code)->pd.DataFrame:
    return df


def get_fit_report(X, y, func, days, column: str = 'close') -> pd.DataFrame:
    """对测试数据集获取验证结果

    Args:
        X: 测试数据集
        func: 实现了`predict`方法的sklearn函数
        days: 天数

    Returns:

    """
    Z = X[[column]].rename(columns={column: '当日收盘价'}).join(
        y[[days]].rename(columns={days: '{}日后收盘价'.format(days)}))
    return Z.join(
        pd.DataFrame(func.predict(X), index=X.index).rename(columns={0: '预测值'}))


def plot_report(days, func, X,y, column: str = 'close', title='', subtitle=''):
    r = get_fit_report(X,y, func, days, column)
    line = pyecharts.Line('{} Days'.format(days) if not title else title,
                          subtitle=subtitle)
    for col in r.columns:
        line.add(col, r.index.date, r[col], datazoom_extra_type='both',
             is_datazoom_extra_show=True,
             datazoom_extra_orient='horizontal')
    # line.add('实际值', data.index.date, data[column], datazoom_extra_type='both',
    #          is_datazoom_extra_show=True,
    #          datazoom_extra_orient='horizontal')
    # line.add('预测值', r.index.date, r[0], datazoom_extra_type='both',
    #          is_datazoom_extra_show=True,
    #          datazoom_extra_orient='horizontal')
    return line

# %%
data=get_calc_data(stock_code,s,e)

# %% [markdown]
# 留100条数据作为测试用

# %%
X=packing_calc_data(data,stock_code)
y=create_validate_df_close(X,DAYS)
X = X[X.index.isin(y.index)]

test_size=0.2
random_state=10

# 拆分数据源
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                        test_size=test_size,
                                                        random_state=random_state)

lr=LinearRegression()

lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %% [markdown]
# ## model得分

# %%
lr.score(X_test, y_test)
# Out:
# 0.9504624199353563

# %% [markdown]
# ## 交叉验证：评估估算器性能
#
# 学习预测函数的参数并在相同的数据上进行测试是一个方法上的错误：一个只重复它刚才看到的样本标签的模型会得到一个完美的分数但是却无法预测任何有用的东西 - 看不见的数据。这种情况称为过度拟合。为了避免这种情况，通常的做法是执行（监督的）机器学习实验以将部分可用数据作为测试集保存 。
#
# https://scikit-learn.org/stable/modules/cross_validation.html

# %% [markdown]
# 拟合模型并连续5次计算得分（每次使用不同的分割）来估计线性回归在数据集上的准确性：

# %%
scores = cross_val_score(lr,X,y,cv=10)
scores
# Out:
# array([ 0.40535   ,  0.75784643,  0.67425224,  0.61941016,  0.51683564,
#         0.85384503,  0.89255133,  0.60100887,  0.63329812, -0.97775685])

# %% [markdown]
# 得分估计的平均得分和95％置信区间由下式给出：

# %%
"Accuracy: %0.2f (+/- %0.2f)" % (scores.mean(), scores.std() * 2)
# Out:
# 'Accuracy: 0.50 (+/- 1.02)'

# %% [markdown]
# ### 指定 score 估算器方法
#
# 默认情况下，在每次CV迭代时计算的分数是score 估算器的方法。可以使用评分参数更改此设置：
#
# https://scikit-learn.org/stable/modules/model_evaluation.html#common-cases-predefined-values

# %%
scores = cross_val_score(lr,X,y,cv=10,scoring='explained_variance')
scores
# Out:
# array([0.43702676, 0.77600904, 0.67552203, 0.62755732, 0.53546717,
#        0.85751608, 0.91834929, 0.69412397, 0.66520303, 0.06237667])

# %% [markdown]
# ### 指定不同的数据划分方式
#
# https://scikit-learn.org/stable/modules/classes.html#module-sklearn.model_selection

# %%
from sklearn.model_selection import TimeSeriesSplit

scores = cross_val_score(lr,X,y,cv=TimeSeriesSplit(500))
scores.mean()
# Out:
# -2.6014992905099784e+26

# %% [markdown]
# ## 数据集预处理
#
# https://scikit-learn.org/stable/data_transforms.html#data-transforms

# %%
from sklearn.model_selection import LeavePOut
cross_val_score(lr,X,y,cv=LeavePOut(p=100)).mean()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-73-e5e3d1a45f54> in <module>
#       1 from sklearn.model_selection import LeavePOut
# ----> 2 cross_val_score(lr,X,y,cv=LeavePOut(p=100)).mean()
#
# ~\AppData\Local\conda\conda\envs\finance35\lib\site-packages\sklearn\model_selection\_validation.py in cross_val_score(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, error_score)
#     400                                 fit_params=fit_params,
#     401                                 pre_dispatch=pre_dispatch,
# --> 402                                 error_score=error_score)
#     403     return cv_results['test_score']
#     404
#
# ~\AppData\Local\conda\conda\envs\finance35\lib\site-packages\sklearn\model_selection\_validation.py in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch, return_train_score, return_estimator, error_score)
#     238             return_times=True, return_estimator=return_estimator,
#     239             error_score=error_score)
# --> 240         for train, test in cv.split(X, y, groups))
#     241
#     242     zipped_scores = list(zip(*scores))
#
# ~\AppData\Local\conda\conda\envs\finance35\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self, iterable)
#     918                 self._iterating = self._original_iterator is not None
#     919
# --> 920             while self.dispatch_one_batch(iterator):
#     921                 pass
#     922
#
# ~\AppData\Local\conda\conda\envs\finance35\lib\site-packages\sklearn\externals\joblib\parallel.py in dispatch_one_batch(self, iterator)
#     757                 return False
#     758             else:
# --> 759                 self._dispatch(tasks)
#     760                 return True
#     761
#
# ~\AppData\Local\conda\conda\envs\finance35\lib\site-packages\sklearn\externals\joblib\parallel.py in _dispatch(self, batch)
#     714         with self._lock:
#     715             job_idx = len(self._jobs)
# --> 716             job = self._backend.apply_async(batch, callback=cb)
#     717             # A job can complete so quickly than its callback is
#     718             # called before we get here, causing self._jobs to
#
# ~\AppData\Local\conda\conda\envs\finance35\lib\site-packages\sklearn\externals\joblib\_parallel_backends.py in apply_async(self, func, callback)
#     180     def apply_async(self, func, callback=None):
#     181         """Schedule a func to be run"""
# --> 182         result = ImmediateResult(func)
#     183         if callback:
#     184             callback(result)
#
# ~\AppData\Local\conda\conda\envs\finance35\lib\site-packages\sklearn\externals\joblib\_parallel_backends.py in __init__(self, batch)
#     547         # Don't delay the application, to avoid keeping the input
#     548         # arguments in memory
# --> 549         self.results = batch()
#     550
#     551     def get(self):
#
# ~\AppData\Local\conda\conda\envs\finance35\lib\site-packages\sklearn\externals\joblib\parallel.py in __call__(self)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\AppData\Local\conda\conda\envs\finance35\lib\site-packages\sklearn\externals\joblib\parallel.py in <listcomp>(.0)
#     223         with parallel_backend(self._backend, n_jobs=self._n_jobs):
#     224             return [func(*args, **kwargs)
# --> 225                     for func, args, kwargs in self.items]
#     226
#     227     def __len__(self):
#
# ~\AppData\Local\conda\conda\envs\finance35\lib\site-packages\sklearn\model_selection\_validation.py in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, error_score)
#     526             estimator.fit(X_train, **fit_params)
#     527         else:
# --> 528             estimator.fit(X_train, y_train, **fit_params)
#     529
#     530     except Exception as e:
#
# ~\AppData\Local\conda\conda\envs\finance35\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     483         else:
#     484             self.coef_, self._residues, self.rank_, self.singular_ = \
# --> 485                 linalg.lstsq(X, y)
#     486             self.coef_ = self.coef_.T
#     487
#
# ~\AppData\Local\conda\conda\envs\finance35\lib\site-packages\scipy\linalg\basic.py in lstsq(a, b, cond, overwrite_a, overwrite_b, check_finite, lapack_driver)
#    1233
#    1234                 x, s, rank, info = lapack_func(a1, b1, lwork,
# -> 1235                                                iwork, cond, False, False)
#    1236             else:  # complex data
#    1237                 lwork, rwork, iwork = _compute_lwork(lapack_lwork, m, n,
#
# KeyboardInterrupt:

# %%
from sklearn.model_selection import ShuffleSplit

cross_val_score(lr,X,y,cv=ShuffleSplit(n_splits=500)).mean()
# Out:
# 0.9762945917065329

# %%
plot_report(DAYS,lr,X,y)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="2029b76f209a41378f22ca3a09107c6a" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_2029b76f209a41378f22ca3a09107c6a = echarts.init(document.getElementById('2029b76f209a41378f22ca3a09107c6a'), 'light', {renderer: 'canvas'});
#
# var option_2029b76f209a41378f22ca3a09107c6a = {
#     "tooltip": {
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "triggerOn": "mousemove|click",
#         "borderWidth": 0,
#         "trigger": "item"
#     },
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "data": [
#                 "2006-10-27",
#                 "2006-10-30",
#                 "2006-10-31",
#                 "2006-11-01",
#                 "2006-11-02",
#                 "2006-11-03",
#                 "2006-11-06",
#                 "2006-11-07",
#                 "2006-11-08",
#                 "2006-11-09",
#                 "2006-11-10",
#                 "2006-11-13",
#                 "2006-11-14",
#                 "2006-11-15",
#                 "2006-11-16",
#                 "2006-11-17",
#                 "2006-11-20",
#                 "2006-11-21",
#                 "2006-11-22",
#                 "2006-11-23",
#                 "2006-11-24",
#                 "2006-11-27",
#                 "2006-11-28",
#                 "2006-11-29",
#                 "2006-11-30",
#                 "2006-12-01",
#                 "2006-12-04",
#                 "2006-12-05",
#                 "2006-12-06",
#                 "2006-12-07",
#                 "2006-12-08",
#                 "2006-12-11",
#                 "2006-12-12",
#                 "2006-12-13",
#                 "2006-12-14",
#                 "2006-12-15",
#                 "2006-12-18",
#                 "2006-12-19",
#                 "2006-12-20",
#                 "2006-12-21",
#                 "2006-12-22",
#                 "2006-12-25",
#                 "2006-12-26",
#                 "2006-12-27",
#                 "2006-12-28",
#                 "2006-12-29",
#                 "2007-01-04",
#                 "2007-01-05",
#                 "2007-01-08",
#                 "2007-01-09",
#                 "2007-01-10",
#                 "2007-01-11",
#                 "2007-01-12",
#                 "2007-01-15",
#                 "2007-01-16",
#                 "2007-01-17",
#                 "2007-01-18",
#                 "2007-01-19",
#                 "2007-01-22",
#                 "2007-01-23",
#                 "2007-01-24",
#                 "2007-01-25",
#                 "2007-01-26",
#                 "2007-01-29",
#                 "2007-01-30",
#                 "2007-01-31",
#                 "2007-02-01",
#                 "2007-02-02",
#                 "2007-02-05",
#                 "2007-02-06",
#                 "2007-02-07",
#                 "2007-02-08",
#                 "2007-02-09",
#                 "2007-02-12",
#                 "2007-02-13",
#                 "2007-02-14",
#                 "2007-02-15",
#                 "2007-02-16",
#                 "2007-02-26",
#                 "2007-02-27",
#                 "2007-02-28",
#                 "2007-03-01",
#                 "2007-03-02",
#                 "2007-03-05",
#                 "2007-03-06",
#                 "2007-03-07",
#                 "2007-03-08",
#                 "2007-03-09",
#                 "2007-03-12",
#                 "2007-03-13",
#                 "2007-03-14",
#                 "2007-03-15",
#                 "2007-03-16",
#                 "2007-03-19",
#                 "2007-03-20",
#                 "2007-03-22",
#                 "2007-03-23",
#                 "2007-03-26",
#                 "2007-03-27",
#                 "2007-03-28",
#                 "2007-03-29",
#                 "2007-03-30",
#                 "2007-04-02",
#                 "2007-04-03",
#                 "2007-04-04",
#                 "2007-04-05",
#                 "2007-04-06",
#                 "2007-04-09",
#                 "2007-04-10",
#                 "2007-04-11",
#                 "2007-04-12",
#                 "2007-04-13",
#                 "2007-04-16",
#                 "2007-04-17",
#                 "2007-04-18",
#                 "2007-04-19",
#                 "2007-04-20",
#                 "2007-04-23",
#                 "2007-04-24",
#                 "2007-04-25",
#                 "2007-04-26",
#                 "2007-04-27",
#                 "2007-04-30",
#                 "2007-05-08",
#                 "2007-05-09",
#                 "2007-05-10",
#                 "2007-05-11",
#                 "2007-05-14",
#                 "2007-05-15",
#                 "2007-05-16",
#                 "2007-05-17",
#                 "2007-05-18",
#                 "2007-05-21",
#                 "2007-05-22",
#                 "2007-05-23",
#                 "2007-05-24",
#                 "2007-05-25",
#                 "2007-05-28",
#                 "2007-05-29",
#                 "2007-05-30",
#                 "2007-05-31",
#                 "2007-06-01",
#                 "2007-06-04",
#                 "2007-06-05",
#                 "2007-06-06",
#                 "2007-06-07",
#                 "2007-06-08",
#                 "2007-06-11",
#                 "2007-06-13",
#                 "2007-06-14",
#                 "2007-06-15",
#                 "2007-06-18",
#                 "2007-06-19",
#                 "2007-06-20",
#                 "2007-06-21",
#                 "2007-06-22",
#                 "2007-06-25",
#                 "2007-06-26",
#                 "2007-06-27",
#                 "2007-06-28",
#                 "2007-06-29",
#                 "2007-07-02",
#                 "2007-07-03",
#                 "2007-07-04",
#                 "2007-07-05",
#                 "2007-07-06",
#                 "2007-07-09",
#                 "2007-07-10",
#                 "2007-07-11",
#                 "2007-07-12",
#                 "2007-07-13",
#                 "2007-07-16",
#                 "2007-07-17",
#                 "2007-07-18",
#                 "2007-07-19",
#                 "2007-07-20",
#                 "2007-07-23",
#                 "2007-07-24",
#                 "2007-07-25",
#                 "2007-07-26",
#                 "2007-07-27",
#                 "2007-07-30",
#                 "2007-07-31",
#                 "2007-08-01",
#                 "2007-08-02",
#                 "2007-08-03",
#                 "2007-08-06",
#                 "2007-08-07",
#                 "2007-08-08",
#                 "2007-08-09",
#                 "2007-08-10",
#                 "2007-08-13",
#                 "2007-08-14",
#                 "2007-08-15",
#                 "2007-08-16",
#                 "2007-08-17",
#                 "2007-08-20",
#                 "2007-08-21",
#                 "2007-08-22",
#                 "2007-08-23",
#                 "2007-08-24",
#                 "2007-08-27",
#                 "2007-08-28",
#                 "2007-08-29",
#                 "2007-08-30",
#                 "2007-08-31",
#                 "2007-09-03",
#                 "2007-09-04",
#                 "2007-09-05",
#                 "2007-09-06",
#                 "2007-09-07",
#                 "2007-09-10",
#                 "2007-09-11",
#                 "2007-09-12",
#                 "2007-09-13",
#                 "2007-09-14",
#                 "2007-09-17",
#                 "2007-09-18",
#                 "2007-09-19",
#                 "2007-09-20",
#                 "2007-09-21",
#                 "2007-09-24",
#                 "2007-09-25",
#                 "2007-09-26",
#                 "2007-09-27",
#                 "2007-09-28",
#                 "2007-10-08",
#                 "2007-10-09",
#                 "2007-10-10",
#                 "2007-10-11",
#                 "2007-10-12",
#                 "2007-10-15",
#                 "2007-10-16",
#                 "2007-10-17"

# %%
X1=packing_calc_data(data[-100:],stock_code)
y1=create_validate_df_close(X1,DAYS)
X1 = X1[X1.index.isin(y1.index)]

plot_report(DAYS,lr,X1,y1)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="3f513ed503364fa0acf9293c0b4a24f1" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_3f513ed503364fa0acf9293c0b4a24f1 = echarts.init(document.getElementById('3f513ed503364fa0acf9293c0b4a24f1'), 'light', {renderer: 'canvas'});
#
# var option_3f513ed503364fa0acf9293c0b4a24f1 = {
#     "tooltip": {
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "triggerOn": "mousemove|click",
#         "borderWidth": 0,
#         "trigger": "item"
#     },
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "data": [
#                 "2018-08-28",
#                 "2018-08-29",
#                 "2018-08-30",
#                 "2018-08-31",
#                 "2018-09-03",
#                 "2018-09-04",
#                 "2018-09-05",
#                 "2018-09-06",
#                 "2018-09-07",
#                 "2018-09-10",
#                 "2018-09-11",
#                 "2018-09-12",
#                 "2018-09-13",
#                 "2018-09-14",
#                 "2018-09-17",
#                 "2018-09-18",
#                 "2018-09-19",
#                 "2018-09-20",
#                 "2018-09-21",
#                 "2018-09-25",
#                 "2018-09-26",
#                 "2018-09-27",
#                 "2018-09-28",
#                 "2018-10-08",
#                 "2018-10-09",
#                 "2018-10-10",
#                 "2018-10-11",
#                 "2018-10-12",
#                 "2018-10-15",
#                 "2018-10-16",
#                 "2018-10-17",
#                 "2018-10-18",
#                 "2018-10-19",
#                 "2018-10-22",
#                 "2018-10-23",
#                 "2018-10-24",
#                 "2018-10-25",
#                 "2018-10-26",
#                 "2018-10-29",
#                 "2018-10-30",
#                 "2018-10-31",
#                 "2018-11-01",
#                 "2018-11-02",
#                 "2018-11-05",
#                 "2018-11-06",
#                 "2018-11-07",
#                 "2018-11-08",
#                 "2018-11-09",
#                 "2018-11-12",
#                 "2018-11-13",
#                 "2018-11-14",
#                 "2018-11-15",
#                 "2018-11-16",
#                 "2018-11-19",
#                 "2018-11-20",
#                 "2018-11-21",
#                 "2018-11-22",
#                 "2018-11-23",
#                 "2018-11-26",
#                 "2018-11-27",
#                 "2018-11-28",
#                 "2018-11-29",
#                 "2018-11-30",
#                 "2018-12-03",
#                 "2018-12-04",
#                 "2018-12-05",
#                 "2018-12-06",
#                 "2018-12-07",
#                 "2018-12-10",
#                 "2018-12-11",
#                 "2018-12-12",
#                 "2018-12-13",
#                 "2018-12-14",
#                 "2018-12-17",
#                 "2018-12-18",
#                 "2018-12-19",
#                 "2018-12-20",
#                 "2018-12-21",
#                 "2018-12-24",
#                 "2018-12-25",
#                 "2018-12-26",
#                 "2018-12-27",
#                 "2018-12-28",
#                 "2019-01-02",
#                 "2019-01-03",
#                 "2019-01-04",
#                 "2019-01-07",
#                 "2019-01-08",
#                 "2019-01-09",
#                 "2019-01-10",
#                 "2019-01-11",
#                 "2019-01-14",
#                 "2019-01-15",
#                 "2019-01-16",
#                 "2019-01-17"
#             ],
#             "type": "category",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "splitLine": {
#                 "show": false
#             },
#             "nameGap": 25,
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "boundaryGap": true,
#             "nameLocation": "middle",
#             "inverse": false
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "top": "center",
#         "left": "95%",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "legend": [
#         {
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "data": [
#                 "\u5f53\u65e5\u6536\u76d8\u4ef7",
#                 "5\u65e5\u540e\u6536\u76d8\u4ef7",
#                 "\u9884\u6d4b\u503c"
#             ],
#             "orient": "horizontal",
#             "show": true,
#             "selectedMode": "multiple",
#             "top": "top",
#             "left": "center"
#         }
#     ],
#     "series_id": 1882378,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "title": [
#         {
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "top": "auto",
#             "left": "auto",
#             "text": "5 Days",
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "min": "dataMin",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "type": "value",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "splitLine": {
#                 "show": true
#             },
#             "nameGap": 25,
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "formatter": "{value} "
#             },
#             "boundaryGap": true,
#             "nameLocation": "middle",
#             "inverse": false
#         }
#     ],
#     "series": [
#         {
#             "name": "\u5f53\u65e5\u6536\u76d8\u4ef7",
#             "step": false,
#             "markLine": {
#                 "data": []
#             },
#             "symbolSize": 4,
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": false,
#                     "position": "top"
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 }
#             },
#             "smooth": false,
#             "data": [
#                 [
#                     "2018-08-28",
#                     5.51
#                 ],
#                 [
#                     "2018-08-29",
#                     5.49
#                 ],

# %%
new_df=QA.QAFetch.QATdx.QA_fetch_get_stock_day(stock_code,'2019-01-01',QA.QAUtil.QA_util_datetime_to_strdate(QA.QAUtil.QA_util_date_today()))
new_df=new_df[['open','close','high','low','vol','amount']]
new_df[['amount', 'vol']]=MinMaxScaler().fit_transform(new_df[['amount', 'vol']])
new_df=new_df.rename(columns={'vol':'volume'})
new_df.index=pd.to_datetime(new_df.index)

new_df=packing_calc_data(new_df,stock_code)

new_valid_df=create_validate_df_close(new_df,DAYS)

# %%
plot_report(DAYS,lr,new_df,new_valid_df)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="b97310db26994223af1b50526795db6b" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_b97310db26994223af1b50526795db6b = echarts.init(document.getElementById('b97310db26994223af1b50526795db6b'), 'light', {renderer: 'canvas'});
#
# var option_b97310db26994223af1b50526795db6b = {
#     "tooltip": {
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "triggerOn": "mousemove|click",
#         "borderWidth": 0,
#         "trigger": "item"
#     },
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "data": [
#                 "2019-01-02",
#                 "2019-01-03",
#                 "2019-01-04",
#                 "2019-01-07",
#                 "2019-01-08",
#                 "2019-01-09",
#                 "2019-01-10",
#                 "2019-01-11",
#                 "2019-01-14",
#                 "2019-01-15",
#                 "2019-01-16",
#                 "2019-01-17",
#                 "2019-01-18",
#                 "2019-01-21",
#                 "2019-01-22",
#                 "2019-01-23",
#                 "2019-01-24",
#                 "2019-01-25",
#                 "2019-01-28",
#                 "2019-01-29",
#                 "2019-01-30",
#                 "2019-01-31",
#                 "2019-02-01",
#                 "2019-02-11",
#                 "2019-02-12",
#                 "2019-02-13",
#                 "2019-02-14",
#                 "2019-02-15",
#                 "2019-02-18",
#                 "2019-02-19",
#                 "2019-02-20",
#                 "2019-02-21"
#             ],
#             "type": "category",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "splitLine": {
#                 "show": false
#             },
#             "nameGap": 25,
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "boundaryGap": true,
#             "nameLocation": "middle",
#             "inverse": false
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "top": "center",
#         "left": "95%",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "legend": [
#         {
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "data": [
#                 "\u5f53\u65e5\u6536\u76d8\u4ef7",
#                 "5\u65e5\u540e\u6536\u76d8\u4ef7",
#                 "\u9884\u6d4b\u503c"
#             ],
#             "orient": "horizontal",
#             "show": true,
#             "selectedMode": "multiple",
#             "top": "top",
#             "left": "center"
#         }
#     ],
#     "series_id": 4772429,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "title": [
#         {
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "top": "auto",
#             "left": "auto",
#             "text": "5 Days",
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "min": "dataMin",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "type": "value",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "splitLine": {
#                 "show": true
#             },
#             "nameGap": 25,
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "formatter": "{value} "
#             },
#             "boundaryGap": true,
#             "nameLocation": "middle",
#             "inverse": false
#         }
#     ],
#     "series": [
#         {
#             "name": "\u5f53\u65e5\u6536\u76d8\u4ef7",
#             "step": false,
#             "markLine": {
#                 "data": []
#             },
#             "symbolSize": 4,
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": false,
#                     "position": "top"
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 }
#             },
#             "smooth": false,
#             "data": [
#                 [
#                     "2019-01-02",
#                     5.2
#                 ],
#                 [
#                     "2019-01-03",
#                     5.2
#                 ],
#                 [
#                     "2019-01-04",
#                     5.27
#                 ],
#                 [
#                     "2019-01-07",
#                     5.24
#                 ],
#                 [
#                     "2019-01-08",
#                     5.2
#                 ],
#                 [
#                     "2019-01-09",
#                     5.26
#                 ],
#                 [
#                     "2019-01-10",
#                     5.22
#                 ],
#                 [
#                     "2019-01-11",
#                     5.24
#                 ],
#                 [
#                     "2019-01-14",
#                     5.2
#                 ],
#                 [
#                     "2019-01-15",
#                     5.23
#                 ],
#                 [
#                     "2019-01-16",
#                     5.24
#                 ],
#                 [
#                     "2019-01-17",
#                     5.25
#                 ],
#                 [
#                     "2019-01-18",
#                     5.39
#                 ],
#                 [
#                     "2019-01-21",
#                     5.45
#                 ],
#                 [
#                     "2019-01-22",
#                     5.39
#                 ],
#                 [
#                     "2019-01-23",
#                     5.44
#                 ],
#                 [
#                     "2019-01-24",
#                     5.46
#                 ],
#                 [
#                     "2019-01-25",
#                     5.52
#                 ],
#                 [
#                     "2019-01-28",
#                     5.5
#                 ],
#                 [
#                     "2019-01-29",
#                     5.54
#                 ],
#                 [
#                     "2019-01-30",
#                     5.55
#                 ],
#                 [
#                     "2019-01-31",
#                     5.66

# %%
def plot_report(days, func, X,y, column: str = 'close', title='', subtitle=''):
    r = get_fit_report(X,y, func, days, column)
    line = pyecharts.Line('{} Days'.format(days) if not title else title,
                          subtitle=subtitle)
    for col in r.columns:
        line.add(col, r.index.date, r[col], datazoom_extra_type='both',
             is_datazoom_extra_show=True,
             datazoom_extra_orient='horizontal',
            yaxis_min='dataMin')
    # line.add('实际值', data.index.date, data[column], datazoom_extra_type='both',
    #          is_datazoom_extra_show=True,
    #          datazoom_extra_orient='horizontal')
    # line.add('预测值', r.index.date, r[0], datazoom_extra_type='both',
    #          is_datazoom_extra_show=True,
    #          datazoom_extra_orient='horizontal')
    return line

# %%
get_fit_report(new_df,new_valid_df,lr,DAYS)
# Out:
#             当日收盘价  5日后收盘价       预测值
# date
# 2019-01-24   5.46    5.66  5.453533
# 2019-01-25   5.52    5.65  5.500801
# 2019-01-28   5.50    5.64  5.474241
# 2019-01-29   5.54    5.65  5.514067
# 2019-01-30   5.55    5.71  5.519596
# 2019-01-31   5.66    5.65  5.570472
# 2019-02-01   5.65    5.51  5.602343
# 2019-02-11   5.64    5.60  5.593567
# 2019-02-12   5.65    5.57  5.626585
# 2019-02-13   5.71    5.57  5.635974
# 2019-02-14   5.65    5.58  5.600850
# 2019-02-15   5.51     NaN  5.445225
# 2019-02-18   5.60     NaN  5.537790
# 2019-02-19   5.57     NaN  5.515647
# 2019-02-20   5.57     NaN  5.557004
# 2019-02-21   5.58     NaN  5.583087

# %%
lr.score(new_df[:-5],new_valid_df)
# Out:
# -4.342201649185873

# %%
new_df.shape,new_valid_df.shape
# Out:
# ((16, 6), (11, 1))

# %%
plot_report(DAYS,lr,new_df,new_valid_df)
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="3f5ff0bba5ff45c39e32f9c394713c85" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_3f5ff0bba5ff45c39e32f9c394713c85 = echarts.init(document.getElementById('3f5ff0bba5ff45c39e32f9c394713c85'), 'light', {renderer: 'canvas'});
#
# var option_3f5ff0bba5ff45c39e32f9c394713c85 = {
#     "tooltip": {
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "triggerOn": "mousemove|click",
#         "borderWidth": 0,
#         "trigger": "item"
#     },
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "data": [
#                 "2019-01-24",
#                 "2019-01-25",
#                 "2019-01-28",
#                 "2019-01-29",
#                 "2019-01-30",
#                 "2019-01-31",
#                 "2019-02-01",
#                 "2019-02-11",
#                 "2019-02-12",
#                 "2019-02-13",
#                 "2019-02-14",
#                 "2019-02-15",
#                 "2019-02-18",
#                 "2019-02-19",
#                 "2019-02-20",
#                 "2019-02-21"
#             ],
#             "type": "category",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "splitLine": {
#                 "show": false
#             },
#             "nameGap": 25,
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             },
#             "boundaryGap": true,
#             "nameLocation": "middle",
#             "inverse": false
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "top": "center",
#         "left": "95%",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "legend": [
#         {
#             "textStyle": {
#                 "fontSize": 12
#             },
#             "data": [
#                 "\u5f53\u65e5\u6536\u76d8\u4ef7",
#                 "5\u65e5\u540e\u6536\u76d8\u4ef7",
#                 "\u9884\u6d4b\u503c"
#             ],
#             "orient": "horizontal",
#             "show": true,
#             "selectedMode": "multiple",
#             "top": "top",
#             "left": "center"
#         }
#     ],
#     "series_id": 6978799,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ],
#     "title": [
#         {
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "top": "auto",
#             "left": "auto",
#             "text": "5 Days",
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "min": "dataMin",
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "type": "value",
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "splitLine": {
#                 "show": true
#             },
#             "nameGap": 25,
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 },
#                 "formatter": "{value} "
#             },
#             "boundaryGap": true,
#             "nameLocation": "middle",
#             "inverse": false
#         }
#     ],
#     "series": [
#         {
#             "name": "\u5f53\u65e5\u6536\u76d8\u4ef7",
#             "step": false,
#             "markLine": {
#                 "data": []
#             },
#             "symbolSize": 4,
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": false,
#                     "position": "top"
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": true
#                 }
#             },
#             "smooth": false,
#             "data": [
#                 [
#                     "2019-01-24",
#                     5.46
#                 ],
#                 [
#                     "2019-01-25",
#                     5.52
#                 ],
#                 [
#                     "2019-01-28",
#                     5.5
#                 ],
#                 [
#                     "2019-01-29",
#                     5.54
#                 ],
#                 [
#                     "2019-01-30",
#                     5.55
#                 ],
#                 [
#                     "2019-01-31",
#                     5.66
#                 ],
#                 [
#                     "2019-02-01",
#                     5.65
#                 ],
#                 [
#                     "2019-02-11",
#                     5.64
#                 ],
#                 [
#                     "2019-02-12",
#                     5.65
#                 ],
#                 [
#                     "2019-02-13",
#                     5.71
#                 ],
#                 [
#                     "2019-02-14",
#                     5.65
#                 ],
#                 [
#                     "2019-02-15",
#                     5.51
#                 ],
#                 [
#                     "2019-02-18",
#                     5.6
#                 ],
#                 [
#                     "2019-02-19",
#                     5.57
#                 ],
#                 [
#                     "2019-02-20",
#                     5.57
#                 ],
#                 [
#                     "2019-02-21",
#                     5.56
#                 ]
#             ],
#             "symbol": "emptyCircle",
#             "seriesId": 6978799,
#             "type": "line",
#             "areaStyle": {
#                 "opacity": 0
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "lineStyle": {
#                 "normal": {
#                     "curveness": 0,
#                     "type": "solid",
#                     "opacity": 1,
#                     "width": 1
#                 }
#             },
#             "showSymbol": true
#         },
#         {
#             "name": "5\u65e5\u540e\u6536\u76d8\u4ef7",
#             "step": false,
#             "markLine": {
#                 "data": []
#             },
#             "symbolSize": 4,
#             "label": {
#                 "normal": {
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "show": false,
#                     "position": "top"
#                 },
#                 "emphasis": {
#                     "textStyle": {
#                         "f
